# %%
import sys

# %%
import pandas as pd

# %%
#a bit of code is a module, a collection of modules is a library, a collection of libaries is a package
#pandas is a open source library, http://pandas.pydata.org/
#pandas does everything that Excel does and more
#pandas uses a dataframe theme to handle data (similar to R)

# %%
#the data are in ../Users/jason/Documents/Re__Jupyter_notebooks_for_today%27s_class

# %%
import seaborn as sns
#visualization package; see https://seaborn.pydata.org/

# %%
# %matplotlib inline
# put visualization inline in the notebook at not as outbook

# %%
#read titanic dataset as pandas dataframe
my_df = pd.read_csv("/Users/jason/Documents/Re__Jupyter_notebooks_for_today%27s_class/Titanic.csv")
#find dimensions of dataframe
my_df.shape
# Out:
# (891, 12)

# %%
#look at top five rows of dataframe
my_df.head(n=5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#select any column by column name
my_df[["Ticket","Fare"'']]
# Out:
#                Ticket      Fare
# 0           A/5 21171    7.2500
# 1            PC 17599   71.2833
# 2    STON/O2. 3101282    7.9250
# 3              113803   53.1000
# 4              373450    8.0500
# 5              330877    8.4583
# 6               17463   51.8625
# 7              349909   21.0750
# 8              347742   11.1333
# 9              237736   30.0708
# 10            PP 9549   16.7000
# 11             113783   26.5500
# 12          A/5. 2151    8.0500
# 13             347082   31.2750
# 14             350406    7.8542
# 15             248706   16.0000
# 16             382652   29.1250
# 17             244373   13.0000
# 18             345763   18.0000
# 19               2649    7.2250
# 20             239865   26.0000
# 21             248698   13.0000
# 22             330923    8.0292
# 23             113788   35.5000
# 24             349909   21.0750
# 25             347077   31.3875
# 26               2631    7.2250
# 27              19950  263.0000
# ...

# %%
#select first three columns by integer position
my_df.iloc[ : ,:3]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# ...

# %%
#select first row by integer position
my_df.iloc[0:1, :] #[[row address, column address]]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
#select specific row that match a given condition
selectfm_df = my_df[my_df["Sex"] == "female"]
selectfm_df.shape
# Out:
# (314, 12)

# %%
# how to sort a dataframe
sorted_df = my_df.sort(columns = "Name", inplace = False) #inplace = False argument prevents overwriting the dataframe
sorted_df.head()
# Out:
# /Users/jason/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
#
#         Sex   Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 845    male  42.0      0      0  C.A. 5547   7.55   NaN        S
# 746    male  16.0      1      1  C.A. 2673  20.25   NaN        S
# 279  female  35.0      1      1  C.A. 2673  20.25   NaN        S
# 308    male  30.0      1      0  P/PP 3381  24.00   NaN        C
# ...

# %%
# how to transpose a dataframe
my_df_T = my_df.T
my_df_T.head()
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
#
#                                 2    \
# PassengerId                       3
# Survived                          1
# Pclass                            3
# Name         Heikkinen, Miss. Laina
# Sex                          female
#
#                                                       3    \
# PassengerId                                             4
# ...

# %%
#how many passengers are male
selectmale_df = my_df[my_df["Sex"] == "male"]
selectmale_df.shape
# Out:
# (577, 12)

# %%
#how many passengers are female
selectfemale_df = my_df[my_df["Sex"] == "female"]
selectfemale_df.shape
# Out:
# (314, 12)

# %%
#number of male survivors
malesurvivor = selectmale_df = selectmale_df[selectmale_df["Survived"] == 1]
malesurvivor.shape
# Out:
# (109, 12)

# %%
#number of female survivors
femalesurvivor = selectfemale_df = selectfemale_df[selectfemale_df["Survived"] == 1]
femalesurvivor.shape
# Out:
# (233, 12)

# %%
#number of passengers under 25
my_df[my_df["Age"]>25].shape
# Out:
# (413, 12)

# %%
#number of female survivors under 50
femalesurvivor[femalesurvivor["Age"]< 50].shape
# Out:
# (177, 12)

# %%
#or
selectfemale_df[(selectfemale_df["Survived"] == 1) & (selectfemale_df["Age"] <50)].shape
# Out:
# (177, 12)

# %%
#all passengers sorted by age
sorted_by_age = my_df.sort(columns = "Age", inplace =  False)
sorted_by_age.head()
# Out:
# /Users/jason/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# ...
